# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait, Select
from selenium.webdriver.support import expected_conditions as EC
import time

# 📌 1. 브라우저 설정
options = Options()
#options.add_argument("--headless")  # 창 띄우지 않음 (개발 중이라면 주석 처리해도 됨)
#options.add_argument("--window-size=1920,1080")
driver = webdriver.Chrome(options=options)

# 📌 2. 사이트 접속
driver.get("https://tmacs.kotsa.or.kr/web/TG/TG300/TG3100/Tg2127.jsp?mid=S1810")
WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.ID, "sido")))

# 📌 3. '서울' 선택
Select(driver.find_element(By.ID, "sido")).select_by_visible_text("서울")
time.sleep(2)

# 📌 4. '강남구' 선택
Select(driver.find_element(By.ID, "jijace")).select_by_visible_text("강남구")
time.sleep(2)

# 📌 5. 조회 버튼 클릭
driver.find_element(By.XPATH, "//a[contains(@class, 'btn_primary')]").click()
time.sleep(3)  # 데이터 로딩 시간

# 📌 6. 결과 그리드 셀 div 모두 가져오기
divs = WebDriverWait(driver, 10).until(
    EC.presence_of_all_elements_located((By.CSS_SELECTOR, "#rMateH5__Content69 > div"))
)

print(f"✅ {len(divs)}개의 셀 div 감지됨")

# 📌 7. 하나씩 셀 클릭 → 팝업 열기 → 3초 후 닫기
main_window = driver.current_window_handle

for idx, div in enumerate(divs):
    try:
        print(f"\n▶ {idx+1}/{len(divs)}번째 셀 클릭 시도 중...")

        # 스크롤해서 보이게 하고 클릭
        driver.execute_script("arguments[0].scrollIntoView(true);", div)
        time.sleep(0.3)
        driver.execute_script("arguments[0].click();", div)

        # 새 창 열릴 때까지 기다림
        WebDriverWait(driver, 10).until(lambda d: len(d.window_handles) > 1)

        # 새 창 핸들로 전환
        for handle in driver.window_handles:
            if handle != main_window:
                popup_window = handle
                break
        driver.switch_to.window(popup_window)

        # 팝업 내용 대기 및 일부 출력
        WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.TAG_NAME, "body")))
        print(f"✅ 팝업 열림: {driver.title}")
        time.sleep(3)  # 📌 3초 유지

        # 팝업 닫기
        driver.close()
        driver.switch_to.window(main_window)

    except Exception as e:
        print(f"❌ {idx+1}번 셀에서 오류 발생: {e}")
        driver.switch_to.window(main_window)
        continue

print("\n🎉 모든 셀 클릭 및 팝업 처리 완료!")
driver.quit()
# Out:
# ✅ 24개의 셀 div 감지됨
#
# ▶ 1/24번째 셀 클릭 시도 중...
# ❌ 1번 셀에서 오류 발생: Message:
#
#
# ▶ 2/24번째 셀 클릭 시도 중...
# ✅ 팝업 열림: 교통안전정보관리시스템
#
# ▶ 3/24번째 셀 클릭 시도 중...
# ✅ 팝업 열림: 교통안전정보관리시스템
#
# ▶ 4/24번째 셀 클릭 시도 중...
# ✅ 팝업 열림: 교통안전정보관리시스템
#
# ▶ 5/24번째 셀 클릭 시도 중...
# ✅ 팝업 열림: 교통안전정보관리시스템
#
# ▶ 6/24번째 셀 클릭 시도 중...
# ✅ 팝업 열림: 교통안전정보관리시스템
#
# ▶ 7/24번째 셀 클릭 시도 중...
# ✅ 팝업 열림: 교통안전정보관리시스템
#
# ▶ 8/24번째 셀 클릭 시도 중...
# ✅ 팝업 열림: 교통안전정보관리시스템
#
# ▶ 9/24번째 셀 클릭 시도 중...
# ✅ 팝업 열림: 교통안전정보관리시스템
#
# ▶ 10/24번째 셀 클릭 시도 중...
# ✅ 팝업 열림: 교통안전정보관리시스템
#
# ▶ 11/24번째 셀 클릭 시도 중...
# ✅ 팝업 열림: 교통안전정보관리시스템
#
# ▶ 12/24번째 셀 클릭 시도 중...
# ✅ 팝업 열림: 교통안전정보관리시스템
#
# ▶ 13/24번째 셀 클릭 시도 중...
# ✅ 팝업 열림: 교통안전정보관리시스템
#
# ▶ 14/24번째 셀 클릭 시도 중...
# ✅ 팝업 열림: 교통안전정보관리시스템
#
# ▶ 15/24번째 셀 클릭 시도 중...
# ✅ 팝업 열림: 교통안전정보관리시스템
#
# ▶ 16/24번째 셀 클릭 시도 중...
# ❌ 16번 셀에서 오류 발생: Message:
#
#
# ▶ 17/24번째 셀 클릭 시도 중...
# ❌ 17번 셀에서 오류 발생: Message:
#
#
# ▶ 18/24번째 셀 클릭 시도 중...
# ❌ 18번 셀에서 오류 발생: Message:
#
#
# ▶ 19/24번째 셀 클릭 시도 중...
# ❌ 19번 셀에서 오류 발생: Message:
#
#
# ▶ 20/24번째 셀 클릭 시도 중...
# ❌ 20번 셀에서 오류 발생: Message:
#
#
# ▶ 21/24번째 셀 클릭 시도 중...
# ❌ 21번 셀에서 오류 발생: Message:
#
#
# ▶ 22/24번째 셀 클릭 시도 중...
# ❌ 22번 셀에서 오류 발생: Message:
#
#
# ▶ 23/24번째 셀 클릭 시도 중...
# ❌ 23번 셀에서 오류 발생: Message:
#
#
# ▶ 24/24번째 셀 클릭 시도 중...
# ❌ 24번 셀에서 오류 발생: Message:
#
#
# 🎉 모든 셀 클릭 및 팝업 처리 완료!

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait, Select
from selenium.webdriver.support import expected_conditions as EC
import time

# 📌 1. 브라우저 설정
options = Options()
#options.add_argument("--headless")  # 창 띄우지 않음 (개발 중이라면 주석 처리해도 됨)
#options.add_argument("--window-size=1920,1080")
driver = webdriver.Chrome(options=options)

# 📌 2. 사이트 접속
driver.get("https://tmacs.kotsa.or.kr/web/TG/TG300/TG3100/Tg2127.jsp?mid=S1810")
WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.ID, "sido")))

# 📌 3. '서울' 선택
Select(driver.find_element(By.ID, "sido")).select_by_visible_text("서울")
time.sleep(2)

# 📌 4. '강남구' 선택
Select(driver.find_element(By.ID, "jijace")).select_by_visible_text("강남구")
time.sleep(2)

# 📌 5. 조회 버튼 클릭
driver.find_element(By.XPATH, "//a[contains(@class, 'btn_primary')]").click()
time.sleep(3)  # 데이터 로딩 시간

# 📌 6. 결과 그리드 셀 div 모두 가져오기
divs = WebDriverWait(driver, 10).until(
    EC.presence_of_all_elements_located((By.CSS_SELECTOR, "#rMateH5__Content69 > div"))
)

print(f"✅ {len(divs)}개의 셀 div 감지됨")

# 📌 7. 하나씩 셀 클릭 → 팝업 열기 → 3초 후 닫기
main_window = driver.current_window_handle

accident_locations = []

for idx, div in enumerate(divs):
    try:
        print(f"\n▶ {idx+1}/{len(divs)}번째 셀 클릭 시도 중...")

        driver.execute_script("arguments[0].scrollIntoView(true);", div)
        time.sleep(0.3)
        driver.execute_script("arguments[0].click();", div)

        WebDriverWait(driver, 10).until(lambda d: len(d.window_handles) > 1)

        for handle in driver.window_handles:
            if handle != main_window:
                popup_window = handle
                break
        driver.switch_to.window(popup_window)

        WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.TAG_NAME, "body")))

        # 사고장소 추출 시도
        try:
            accident_location_elem = driver.find_element(By.XPATH, "//th[contains(text(), '사고장소')]/following-sibling::td")
        except:
            try:
                accident_location_elem = driver.find_element(By.XPATH, "//dt[contains(text(), '사고장소')]/following-sibling::dd[1]")
            except:
                accident_location_elem = None

        if accident_location_elem:
            accident_location = accident_location_elem.text.strip()
        else:
            accident_location = "❓ 사고장소 정보 없음"

        print(f"📍 사고장소: {accident_location}")
        accident_locations.append(accident_location)

        time.sleep(1.5)
        driver.close()
        driver.switch_to.window(main_window)

    except Exception as e:
        print(f"❌ {idx+1}번 셀에서 오류 발생: {e}")
        driver.switch_to.window(main_window)
        continue

# 저장
import pandas as pd
df = pd.DataFrame({'사고장소': accident_locations})
df.to_csv("accident_locations.csv", index=False, encoding='utf-8-sig')
# Out:
# ✅ 24개의 셀 div 감지됨
#
# ▶ 1/24번째 셀 클릭 시도 중...
# ❌ 1번 셀에서 오류 발생: Message:
#
#
# ▶ 2/24번째 셀 클릭 시도 중...
# 📍 사고장소: 역삼동 교보타워사거리
#
# ▶ 3/24번째 셀 클릭 시도 중...
# 📍 사고장소: 논현동 차병원사거리
#
# ▶ 4/24번째 셀 클릭 시도 중...
# 📍 사고장소: 논현동 강남을지병원사거리
#
# ▶ 5/24번째 셀 클릭 시도 중...
# 📍 사고장소: 역삼동 르네상스호텔사거리
#
# ▶ 6/24번째 셀 클릭 시도 중...
# 📍 사고장소: 논현동 경복아파트앞교차로
#
# ▶ 7/24번째 셀 클릭 시도 중...
# 📍 사고장소: 삼성동 삼성동현대백화점
#
# ▶ 8/24번째 셀 클릭 시도 중...
# 📍 사고장소: 대치동 대치우성아파트앞교차로
#
# ▶ 9/24번째 셀 클릭 시도 중...
# 📍 사고장소: 삼성동 코엑스앞교차로
#
# ▶ 10/24번째 셀 클릭 시도 중...
# 📍 사고장소: 청담동 학동사거리
#
# ▶ 11/24번째 셀 클릭 시도 중...
# 📍 사고장소: 논현동 학동역교차로
#
# ▶ 12/24번째 셀 클릭 시도 중...
# 📍 사고장소: 수서동 수서역앞교차로
#
# ▶ 13/24번째 셀 클릭 시도 중...
# 📍 사고장소: 신사동 신사역사거리
#
# ▶ 14/24번째 셀 클릭 시도 중...
# 📍 사고장소: 도곡동 양재전화국교차로
#
# ▶ 15/24번째 셀 클릭 시도 중...
# 📍 사고장소: 삼성동 선릉역사거리
#
# ▶ 16/24번째 셀 클릭 시도 중...
# ❌ 16번 셀에서 오류 발생: Message:
#
#
# ▶ 17/24번째 셀 클릭 시도 중...
# ❌ 17번 셀에서 오류 발생: Message:
#
#
# ▶ 18/24번째 셀 클릭 시도 중...
# ❌ 18번 셀에서 오류 발생: Message:
#
#
# ▶ 19/24번째 셀 클릭 시도 중...
# ❌ 19번 셀에서 오류 발생: Message:
#
#
# ▶ 20/24번째 셀 클릭 시도 중...
# ❌ 20번 셀에서 오류 발생: Message:
#
#
# ▶ 21/24번째 셀 클릭 시도 중...
# ❌ 21번 셀에서 오류 발생: Message:
#
#
# ▶ 22/24번째 셀 클릭 시도 중...
# ❌ 22번 셀에서 오류 발생: Message:
#
#
# ▶ 23/24번째 셀 클릭 시도 중...
# ❌ 23번 셀에서 오류 발생: Message:
#
#
# ▶ 24/24번째 셀 클릭 시도 중...
# ❌ 24번 셀에서 오류 발생: Message:

# %%
df
# Out:
#                사고장소
# 0       역삼동 교보타워사거리
# 1        논현동 차병원사거리
# 2     논현동 강남을지병원사거리
# 3     역삼동 르네상스호텔사거리
# 4     논현동 경복아파트앞교차로
# 5      삼성동 삼성동현대백화점
# 6   대치동 대치우성아파트앞교차로
# 7       삼성동 코엑스앞교차로
# 8         청담동 학동사거리
# 9        논현동 학동역교차로
# 10      수서동 수서역앞교차로
# 11       신사동 신사역사거리
# 12     도곡동 양재전화국교차로
# 13       삼성동 선릉역사거리
