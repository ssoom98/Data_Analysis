# %%
import pandas as pd
df = pd.read_csv('../../User/Desktop/miniproject/where2go/data/east/TL_csv/tn_activity_consume_his_활동소비내역_B.csv')
df1 = pd.read_csv('../../User/Desktop/miniproject/where2go/data/east/TL_csv/tn_activity_his_활동내역_B.csv')
df2 = pd.read_csv('../../User/Desktop/miniproject/where2go/data/east/TL_csv/tn_traveller_master_여행객 Master_B.csv')
df3 = pd.read_csv('../../User/Desktop/miniproject/where2go/data/east/TL_csv/tn_visit_area_info_방문지정보_B.csv')
df4 = pd.read_csv('../../User/Desktop/miniproject/where2go/data/east/TL_csv/tn_companion_info_동반자정보_B.csv')
df5 = pd.read_csv('../../User/Desktop/miniproject/where2go/data/east/TL_csv/tn_travel_여행_B.csv')
df6 = pd.read_csv('../../User/Desktop/miniproject/where2go/data/east/VL_csv/tn_travel_여행_B.csv')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_45800\3157615419.py:5: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df3 = pd.read_csv('../../User/Desktop/miniproject/where2go/data/east/TL_csv/tn_visit_area_info_방문지정보_B.csv')

# %%
df
# Out:
#        TRAVEL_ID  VISIT_AREA_ID  ACTIVITY_TYPE_CD  ACTIVITY_TYPE_SEQ  \
# 0      b_b011174     2210240003                 2                  1
# 1      b_b004534     2210010001                 1                  0
# 2      b_b005652     2210120003                 1                  0
# 3      b_b006597     2210160004                 2                  4
# 4      b_b002171     2208210004                 1                  0
# ...          ...            ...               ...                ...
# 19819  b_b000387     2208170002                 1                  0
# 19820  b_b005679     2210020003                 1                  0
# 19821  b_b005672     2210020009                 1                  0
# 19822  b_b001387     2208200003                 3                  0
# 19823  b_b009565     2210290004                 1                  2
#
#        CONSUME_HIS_SEQ  CONSUME_HIS_SNO  PAYMENT_NUM          BRNO  \
# 0                    1                1            1           NaN
# ...

# %%
df = df[["TRAVEL_ID","PAYMENT_NUM","PAYMENT_AMT_WON","PAYMENT_ETC"]]
df.sort_values()

# %%
df[df['TRAVEL_ID']=='b_b001813']
# Out:
#        TRAVEL_ID  VISIT_AREA_ID  ACTIVITY_TYPE_CD  ACTIVITY_TYPE_SEQ  \
# 1479   b_b001813     2208220004                 3                  0
# 1870   b_b001813     2208230003                 1                  0
# 4371   b_b001813     2208220007                 1                  0
# 4514   b_b001813     2208230004                 1                  0
# 7369   b_b001813     2208220001                 1                  0
# 7608   b_b001813     2208210003                 1                  0
# 8108   b_b001813     2208220006                 6                  2
# 8654   b_b001813     2208230001                 1                  0
# 8738   b_b001813     2208230006                 1                  2
# 9971   b_b001813     2208220008                 1                  3
# 11790  b_b001813     2208220002                 2                  0
# 15017  b_b001813     2208230005                 1                  0
# 15935  b_b001813     2208220003                 1                  0
# ...

# %%
df3[df3['TRAVEL_ID']== 'b_b002161'].sort_values(by=['VISIT_ORDER']).reset_index(drop=True)
# Out:
#     VISIT_AREA_ID  TRAVEL_ID  VISIT_ORDER  VISIT_AREA_NM VISIT_START_YMD  \
# 0      2208220001  b_b002161            1              집      2022-08-22
# 1      2208220002  b_b002161            2         오아시스정글      2022-08-22
# 2      2208230001  b_b002161            3     백담계곡 트레킹코스      2022-08-23
# 3      2208230003  b_b002161            4          평화막국수      2022-08-23
# 4      2208230002  b_b002161            5  엘림게스트하우스 인 속초      2022-08-23
# 5      2208240002  b_b002161            7         미아모르모텔      2022-08-24
# 6      2208250001  b_b002161            8  강릉대관령휴게소 인천방향      2022-08-25
# 7      2208250003  b_b002161           10              집      2022-08-25
# 8      2208260001  b_b002161           11              집      2022-08-26
# 9      2208270001  b_b002161           12              집      2022-08-27
# 10     2208290001  b_b002161           14              집      2022-08-29
# 11     2208310001  b_b002161           16              집      2022-08-31
# ...

# %%
숙박을 한사람들과 숙박을 안한 사람들의 소비 차이 
-
# Out:
#   Cell In[7], line 1
#     숙박을 한사람들과 숙박을 안한 사람들의 소비 차이
#         ^
# SyntaxError: invalid syntax

# %%
df5
# Out:
#       TRAVEL_ID TRAVEL_NM TRAVELER_ID TRAVEL_PURPOSE TRAVEL_START_YMD  \
# 0     b_b015715       B04     b015715            22;       2022-10-29
# 1     b_b000419       B01     b000419            21;       2022-08-06
# 2     b_b013638       B01     b013638            28;       2022-11-05
# 3     b_b007836       B02     b007836  13;24;26;3;4;       2022-10-18
# 4     b_b004718       B04     b004718      1;26;6;9;       2022-10-01
# ...         ...       ...         ...            ...              ...
# 3195  b_b003962       B03     b003962           2;8;       2022-09-17
# 3196  b_b006646       B01     b006646     9;11;9;11;       2022-10-07
# 3197  b_b015565       B03     b015565             2;       2022-10-29
# 3198  b_b002136       B01     b002136   10;28;3;4;5;       2022-08-26
# 3199  b_b004063       B03     b004063     1;3;4;6;9;       2022-09-23
#
#      TRAVEL_END_YMD MVMN_NM       TRAVEL_PERSONA TRAVEL_MISSION  \
# ...

# %%
# Out:
#       TRAVEL_ID TRAVEL_NM TRAVELER_ID TRAVEL_PURPOSE TRAVEL_START_YMD  \
# 0     b_b015715       B04     b015715            22;       2022-10-29
# 1     b_b000419       B01     b000419            21;       2022-08-06
# 2     b_b013638       B01     b013638            28;       2022-11-05
# 3     b_b007836       B02     b007836  13;24;26;3;4;       2022-10-18
# 4     b_b004718       B04     b004718      1;26;6;9;       2022-10-01
# ...         ...       ...         ...            ...              ...
# 3195  b_b003962       B03     b003962           2;8;       2022-09-17
# 3196  b_b006646       B01     b006646     9;11;9;11;       2022-10-07
# 3197  b_b015565       B03     b015565             2;       2022-10-29
# 3198  b_b002136       B01     b002136   10;28;3;4;5;       2022-08-26
# 3199  b_b004063       B03     b004063     1;3;4;6;9;       2022-09-23
#
#      TRAVEL_END_YMD MVMN_NM       TRAVEL_PERSONA TRAVEL_MISSION  \
# ...

# %%
combined_df = pd.concat([df5, df6], ignore_index=True)

# %%
combined_df['TRAVEL_END_YMD']= pd.to_datetime(combined_df['TRAVEL_END_YMD'])
combined_df['TRAVEL_START_YMD']= pd.to_datetime(combined_df['TRAVEL_START_YMD'])
combined_df['TRAVEL_DAYS'] = (combined_df['TRAVEL_END_YMD'] - combined_df['TRAVEL_START_YMD']).dt.days

# %%
combined_df['TRAVEL_DAYS'].value_counts()
# Out:
# 2     1597
# 3     1388
# 4      484
# 5       92
# 6       25
# 8        7
# 7        5
# 9        1
# 18       1
# Name: TRAVEL_DAYS, dtype: int64

# %%
당일치기(1817)+무박2일와 숙박한사람들의 하루평균결제금액에 차이가 없다(숙박결제금액뺀다-> 숙박유형코드가 남는다 2,  7 이런식 )
1856 1940
그러면 우리가 가지가야할 컬럼은 여행아이

# %%
import pandas as pd
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.patches as mpatches
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False
# 원페이퍼 템플릿 구조를 그림 형태로 생성
fig = plt.figure(figsize=(10, 14))
gs = gridspec.GridSpec(6, 1, height_ratios=[0.8, 1, 1, 1, 1, 1.2])
fig, axes = plt.subplots(1, 6, figsize=(20, 6))

# 각 항목 내용
titles = [
    "1. 연구 배경 및 목적",
    "2. 가설 및 데이터",
    "3. 분석 방법",
    "4. 시각화 요약",
    "5. 결과 요약",
    "6. 인사이트 및 시사점"
]

contents = [
    "- 불일치율 = 말한 동기 vs 실제 방문의 불일치 정도\n- 마케팅, 정책, 추천 시스템 정밀도 향상에 기여",
    "- 가설1: 연령대별 차이 없음\n- 가설2: 동반자 유형별 차이 없음\n- 데이터: 동부권 여행 로그\n- 정규성 검정 → 비모수 사용",
    "- Kruskal-Wallis H-test\n- Dunn’s post-hoc test (동반자 유형)\n- 그룹 간 차이 분석",
    "- 연령대별 Boxplot\n- 동반자 유형별 Boxplot\n- 일부 그룹 간 시각적 차이 확인",
    "- 연령대별 p < 0.05 → 유의미함\n- 동반자 유형 p < 0.05 → 유의미함\n- 특히 혼자 vs 3인 이상 차이 큼",
    "- 불일치율 높은 그룹 → 행동 기반 추천 필요\n- 정책/마케팅 타깃 세분화 필요\n- 진술 기반 전략의 한계 보완"
]

# 시각화
for ax, title, content in zip(axes, titles, contents):
    ax.axis('off')
    ax.set_title(title, fontsize=11, fontweight='bold', loc='left')
    ax.text(0, 1, content, ha='left', va='top', fontsize=9, wrap=True, linespacing=1.5)

plt.tight_layout()
plt.show()
